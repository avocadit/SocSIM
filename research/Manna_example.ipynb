# %% [markdown]
# # Manna model

# %%
cd ..
# Out:
# /aktualne/git_repozytoria/git_SOC/SocSIM

# %%
import SOC.models

# %%
modele={}
for ii in range(0,20,1):
    modele[ii] = SOC.models.Manna(100)
    modele[ii].run(20000)

# %%
#model.animate_states(notebook=True)

# %%
#heights, bin_edges = model.plot_histogram(num=50)

# %%
params=[]
for ii in range(0,20,1):
    params.append(modele[ii].get_exponent(hist_num=100, smooth_width = 50, plot = True))
# Out:
# [ 1.92264305 -0.5188086 ]
# [ 1.91957575 -0.51934629]
# [ 1.87606253 -0.43163568]
# [ 1.96842932 -0.47575109]
# [ 1.93899149 -0.50235071]
# [ 1.91692569 -0.52718653]
# [ 1.95704954 -0.47787523]
# [ 1.99928549 -0.40821843]
# [ 1.92924278 -0.51668461]
# [ 1.9298007  -0.51019699]
# [ 1.91927231 -0.52848508]
# [ 2.04443893 -0.38509166]
# [ 1.9257845  -0.51554358]
# [ 1.91786244 -0.51549869]
# [ 1.93236213 -0.52547009]
# [ 1.93185911 -0.52016501]
# [ 1.93171735 -0.49180241]
# [ 1.95262829 -0.49036399]
# [ 1.92960787 -0.50983663]
# [ 1.92827965 -0.50611254]

# %%
10./7.
# Out:
# 1.4285714285714286

# %%
print(params)
# Out:
# [-0.5188085958102538, -0.5193462947242341, -0.43163567612189097, -0.47575109421094114, -0.5023507121669599, -0.5271865287414974, -0.47787523488344325, -0.4082184303022326, -0.5166846149238538, -0.5101969852062933, -0.5284850798808769, -0.3850916570898975, -0.5155435787936171, -0.515498694444494, -0.5254700946241727, -0.5201650145591894, -0.49180241314601625, -0.4903639948649262, -0.5098366346003728, -0.5061125407923577]
